# %% [markdown]
# # Del 2 – Fördjupning och pipeline
# ## Klassbaserad analys av hälsodata

# %%
import numpy as np
from src.metrics import ladda_data
from src.analyzer import HealthAnalyzer

data = ladda_data()
analyzer = HealthAnalyzer(data)

# %% [markdown]
# I denna del används klassen HealthAnalyzer för att samla analysmetoder.
# Koden byggs vidare från Del 1 men struktureras objektorienterat för bättre översikt.

# %% [markdown]
# ### Linjär regression

# %%
analyzer.regression_bp()
analyzer.plot_regression()
# Out:
# Regression klar!
# Intercept: 144.76
# Koefficienter: {'age': np.float64(-0.06), 'weight': np.float64(-0.03)}

# %% [markdown]
# En enkel linjär regression används för att se sambandet mellan ålder, vikt och blodtryck.
# Modellen bygger på ordinär minsta kvadrat och implementeras med
# scikit-learn.LinearRegression.

# %% [markdown]
# ### Ny analys – sjukdomsförekomst per kön

# %%
analyzer.sjukdom_per_koen()

# %% [markdown]
# Denna graf visar hur sjukdomsförekomsten skiljer sig mellan män och kvinnor.
# Staplarna representerar andelen sjuka i varje grupp.

# %% [markdown]
# ## Sammanfattning
# - Klassen `HealthAnalyzer` gör analysen mer strukturerad.
# - Regressionen visar hur blodtryck påverkas av ålder och vikt.
# - Den nya visualiseringen visar skillnader i sjukdomsförekomst mellan könen.
